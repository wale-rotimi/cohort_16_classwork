# %%
import numpy as np

# %%
nums=np.array([1, 3, 5, 7, 9])
print(nums)
# Out:
# [1 3 5 7 9]

# %%
nums_plus_2=nums+2
print(nums_plus_2)
# Out:
# [ 3  5  7  9 11]

# %%
nums_plus_2*3
# Out:
# array([ 9, 15, 21, 27, 33])

# %%
num_sum=np.sum(nums)
print(num_sum)
# Out:
# 25

# %%
num_max=np.max(nums)
print(num_max)
# Out:
# 9

# %%
num_mean=np.mean(nums)
print(num_mean)
# Out:
# 5.0
